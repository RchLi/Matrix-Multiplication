# %%
import numpy as np
import matplotlib.pyplot as plt

x = [32, 64, 128, 256, 511, 512, 513, 1023, 1024, 1025, 2047, 2048]
y_naive = [2.1, 1.83, 1.87, 0.882, 1.68, 0.867, 1.69, 1.2, 0.146, 1.13, 0.51, 1.1]
y_4_8 = [0.106, .83, 5.62, 15.2, 20.9, 20.9, 18.4, 22.4, 20.9, 20, 20.1, 21.5] 
y_4_12 = [0.108, .84, 5.78, 15.9, 21.3, 21.9, 19.7, 23.5, 21.7, 20.4, 22.5, 22.6]
y_blas = [17.6, 24, 28.5, 32.6, 33, 34.4, 32.5, 34.4, 34.9, 29.8, 35.1, 35.1]
plt.figure(figsize=(9,6))
plt.plot(x, y_naive, 'gx-.', label = 'Naive')
# plt.plot(x, y_4_8, 'r-*', label = '4*8 Kernel')
plt.plot(x, y_4_12, 'r-*', label = 'Our\'s')
plt.plot(x, y_blas, 'bo-.', label = 'Benchmark')
plt.legend()
plt.grid()
plt.ylim(0, 50)
plt.xlabel('Matrix Size')
plt.ylabel('GFlops')
# Out:
# Text(0, 0.5, 'GFlops')

# %%
import matplotlib.pyplot as plt

# x = [256, 511, 512, 513, 1023, 1024, 1025, 1600, 1664, 2047, 2048]
# y_4_8 = [15.1, 13, 21.3, 19.1, 22.2, 22.8, 19.7, 21.4, 18.1, 21.7, 22.6]  
# y_4_12 = [15.9, 21.4, 20.3, 19.3, 24, 24.2, 17.5, 23.4, 23.6, 23.6, 23.5]
x = [32, 64, 128, 256, 511, 512, 513, 1023, 1024, 1025, 2047, 2048]
y_naive = [2.1, 1.83, 1.87, 0.882, 1.68, 0.867, 1.69, 1.2, 0.146, 1.13, 0.51, 1.1]
y_4_8 = [0.106, .83, 5.62, 15.2, 20.9, 20.9, 18.4, 22.4, 20.9, 20, 20.1, 21.5] 
y_4_12 = [0.108, .84, 5.78, 15.9, 21.3, 21.9, 19.7, 23.5, 21.7, 20.4, 22.5, 22.6]
plt.figure(figsize=(9,6))

plt.plot(x, y_4_8, 'y-*', label = '4*8 Kernel')
plt.plot(x, y_4_12, 'r-*', label = '4*12 Kernel')

plt.legend()
plt.grid()
plt.ylim(0, 30)
plt.xlabel('Matrix Size')
plt.ylabel('GFlops')
# Out:
# Text(0, 0.5, 'GFlops')

# %%
len(y_naive)
# Out:
# 12
